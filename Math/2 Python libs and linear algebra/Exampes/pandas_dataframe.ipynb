# %% [markdown]
# # Библиотека Pandas

# %% [markdown]
# ## Data Frame

# %%
import pandas as pd

# %%
#создание DataFrame по столбцам с помощью словарей
frame = pd.DataFrame({'numbers':range(10), 'chars':['a']*10})

# %%
frame
# Out:
#    numbers chars
# 0        0     a
# 1        1     a
# 2        2     a
# 3        3     a
# 4        4     a
# 5        5     a
# 6        6     a
# 7        7     a
# 8        8     a
# 9        9     a

# %%
#создание DataFrame с помощью чтения данных из файла
frame = pd.read_csv('dataset.tsv', header=0, sep='\t')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-c7f5a8d5ac40> in <module>
#       1 #создание DataFrame с помощью чтения данных из файла
# ----> 2 frame = pd.read_csv('dataset.tsv', header=0, sep='\t')
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     637         if ioargs.encoding and "b" not in ioargs.mode:
#     638             # Encoding
# --> 639             handle = open(
#     640                 handle,
#     641                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dataset.tsv'

# %%
frame
# Out:
#    numbers chars
# 0        0     a
# 1        1     a
# 2        2     a
# 3        3     a
# 4        4     a
# 5        5     a
# 6        6     a
# 7        7     a
# 8        8     a
# 9        9     a

# %%
frame.columns
# Out:
# Index(['numbers', 'chars'], dtype='object')

# %%
frame.shape
# Out:
# (10, 2)

# %%
new_line = {'Name':'Perov', 'Birth':'22.03.1990', 'City':'Penza'}

# %%
#добавление строки в DataFrame
frame.append(new_line, ignore_index=True)
# Out:
#     numbers chars       Birth   City   Name
# 0       0.0     a         NaN    NaN    NaN
# 1       1.0     a         NaN    NaN    NaN
# 2       2.0     a         NaN    NaN    NaN
# 3       3.0     a         NaN    NaN    NaN
# 4       4.0     a         NaN    NaN    NaN
# 5       5.0     a         NaN    NaN    NaN
# 6       6.0     a         NaN    NaN    NaN
# 7       7.0     a         NaN    NaN    NaN
# 8       8.0     a         NaN    NaN    NaN
# 9       9.0     a         NaN    NaN    NaN
# 10      NaN   NaN  22.03.1990  Penza  Perov

# %%
#добавление строки в DataFrame
frame = frame.append(new_line, ignore_index=True)

# %%
frame
# Out:
#     numbers chars       Birth   City   Name
# 0       0.0     a         NaN    NaN    NaN
# 1       1.0     a         NaN    NaN    NaN
# 2       2.0     a         NaN    NaN    NaN
# 3       3.0     a         NaN    NaN    NaN
# 4       4.0     a         NaN    NaN    NaN
# 5       5.0     a         NaN    NaN    NaN
# 6       6.0     a         NaN    NaN    NaN
# 7       7.0     a         NaN    NaN    NaN
# 8       8.0     a         NaN    NaN    NaN
# 9       9.0     a         NaN    NaN    NaN
# 10      NaN   NaN  22.03.1990  Penza  Perov
# 11      NaN   NaN  22.03.1990  Penza  Perov

# %%
#добавление столбца в DataFrame
frame['IsStudent'] = [False]*10 + [True]*2

# %%
frame
# Out:
#     numbers chars       Birth   City   Name  IsStudent
# 0       0.0     a         NaN    NaN    NaN      False
# 1       1.0     a         NaN    NaN    NaN      False
# 2       2.0     a         NaN    NaN    NaN      False
# 3       3.0     a         NaN    NaN    NaN      False
# 4       4.0     a         NaN    NaN    NaN      False
# 5       5.0     a         NaN    NaN    NaN      False
# 6       6.0     a         NaN    NaN    NaN      False
# 7       7.0     a         NaN    NaN    NaN      False
# 8       8.0     a         NaN    NaN    NaN      False
# 9       9.0     a         NaN    NaN    NaN      False
# 10      NaN   NaN  22.03.1990  Penza  Perov       True
# 11      NaN   NaN  22.03.1990  Penza  Perov       True

# %%
#удаление строк DataFrame
frame.drop([5,6], axis=0)
# Out:
#    numbers chars Birth City
# 0      0.0     a   NaN  NaN
# 1      1.0     a   NaN  NaN
# 2      2.0     a   NaN  NaN
# 3      3.0     a   NaN  NaN
# 4      4.0     a   NaN  NaN
# 7      7.0     a   NaN  NaN
# 8      8.0     a   NaN  NaN
# 9      9.0     a   NaN  NaN

# %%
frame
# Out:
#    numbers chars Birth City
# 0      0.0     a   NaN  NaN
# 1      1.0     a   NaN  NaN
# 2      2.0     a   NaN  NaN
# 3      3.0     a   NaN  NaN
# 4      4.0     a   NaN  NaN
# 5      5.0     a   NaN  NaN
# 6      6.0     a   NaN  NaN
# 7      7.0     a   NaN  NaN
# 8      8.0     a   NaN  NaN
# 9      9.0     a   NaN  NaN

# %%
#удаление строк DataFrame (inplace)
frame.drop([10,11], axis=0, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-68-6ae6efa8877e> in <module>
#       1 #удаление строк DataFrame (inplace)
# ----> 2 frame.drop([10,11], axis=0, inplace=True)
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: '[10 11] not found in axis'

# %%
frame
# Out:
#    numbers chars Birth City
# 0      0.0     a   NaN  NaN
# 1      1.0     a   NaN  NaN
# 2      2.0     a   NaN  NaN
# 3      3.0     a   NaN  NaN
# 4      4.0     a   NaN  NaN
# 5      5.0     a   NaN  NaN
# 6      6.0     a   NaN  NaN
# 7      7.0     a   NaN  NaN
# 8      8.0     a   NaN  NaN
# 9      9.0     a   NaN  NaN

# %%
#удаление столбца DataFrame (inplace)
frame.drop('IsStudent', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-e59a42c339ba> in <module>
#       1 #удаление столбца DataFrame (inplace)
# ----> 2 frame.drop('IsStudent', axis=1, inplace=True)
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4303                 weight  1.0     0.8
#    4304         """
# -> 4305         return super().drop(
#    4306             labels=labels,
#    4307             axis=axis,
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/anaconda3/envs/ds_env/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5589         if mask.any():
#    5590             if errors != "ignore":
# -> 5591                 raise KeyError(f"{labels[mask]} not found in axis")
#    5592             indexer = indexer[~mask]
#    5593         return self.delete(indexer)
#
# KeyError: "['IsStudent'] not found in axis"

# %%
frame
# Out:
#    numbers chars Birth City
# 0      0.0     a   NaN  NaN
# 1      1.0     a   NaN  NaN
# 2      2.0     a   NaN  NaN
# 3      3.0     a   NaN  NaN
# 4      4.0     a   NaN  NaN
# 5      5.0     a   NaN  NaN
# 6      6.0     a   NaN  NaN
# 7      7.0     a   NaN  NaN
# 8      8.0     a   NaN  NaN
# 9      9.0     a   NaN  NaN

# %%
#запись DataFrame в файл
frame.to_csv('updated_dataset.csv', sep=',', header=True, index=False)

# %%
# !cat updated_dataset.csv
# Out:
# numbers,chars,Birth,City,Name,IsStudent
# 0.0,a,,,,False
# 1.0,a,,,,False
# 2.0,a,,,,False
# 3.0,a,,,,False
# 4.0,a,,,,False
# 5.0,a,,,,False
# 6.0,a,,,,False
# 7.0,a,,,,False
# 8.0,a,,,,False
# 9.0,a,,,,False
# ,,22.03.1990,Penza,Perov,True
# ,,22.03.1990,Penza,Perov,True

# %%
#аналог команды для пользователей Windows
# !more updated_dataset.csv
# Out:
# numbers,chars,Birth,City,Name,IsStudent
# 0.0,a,,,,False
# 1.0,a,,,,False
# 2.0,a,,,,False
# 3.0,a,,,,False
# 4.0,a,,,,False
# 5.0,a,,,,False
# 6.0,a,,,,False
# 7.0,a,,,,False
# 8.0,a,,,,False
# 9.0,a,,,,False
# ,,22.03.1990,Penza,Perov,True
# ,,22.03.1990,Penza,Perov,True
